# %%
import pandas as pd
import seaborn as sns 
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
auto = pd.read_csv('Automobile+%281%29.csv')

# %%
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
#Univariate distribution
sns.displot(auto['city_mpg'], kde=True, rug=True)
plt.show()

# %%
#Univariate distribution
sns.displot(auto['normalized_losses'], kde=False, rug=True)
plt.show()

# %%
#Bi-variate dstribution using a residual plot (kind='reg')
sns.jointplot(auto['engine_size'], auto['normalized_losses'])
plt.show()
# Out:
# C:\Users\ebuka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Bi-variate dstribution using a residual plot (kind='reg')
sns.jointplot(auto['engine_size'], auto['normalized_losses'], kind="reg")
plt.show()
# Out:
# C:\Users\ebuka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#creating a maxtrix of visualization to explain relationship between variables - MULTI-VARIATE distribution
sns.pairplot(auto[['normalized_losses', 'engine_size', 'horsepower']])

# %%
#plotting a 2d plot(i.e where one plot is a continous variable{int} and the other is categorical{str}) - use the stripplot
sns.stripplot(auto['fuel_type'], auto['horsepower'], jitter=True)
# Out:
# C:\Users\ebuka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fuel_type', ylabel='horsepower'>

# %%
sns.swarmplot(auto['fuel_type'], auto['horsepower'])
# Out:
# C:\Users\ebuka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ebuka\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='fuel_type', ylabel='horsepower'>

# %%
sns.boxplot(auto['number_of_doors'], auto['horsepower'], hue=auto['fuel_type'])
# Out:
# C:\Users\ebuka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_of_doors', ylabel='horsepower'>

# %%
sns.barplot(auto['body_style'], auto['horsepower'], hue=auto['engine_location'])
# Out:
# C:\Users\ebuka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body_style', ylabel='horsepower'>

# %%
sns.countplot(auto['body_style'], hue=auto['engine_location'])
# Out:
# C:\Users\ebuka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body_style', ylabel='count'>

# %%
sns.pointplot(auto['fuel_system'], auto['horsepower'], hue=auto['number_of_doors'])
# Out:
# C:\Users\ebuka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fuel_system', ylabel='horsepower'>

# %%
sns.factorplot(x='fuel_type', 
               y='horsepower', 
               hue='number_of_doors', 
               col='engine_location', 
               data= auto,
               kind='swarm')
# Out:
# C:\Users\ebuka\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\ebuka\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#Linear regression to check the linear relationship between 2 variables
sns.lmplot(x='horsepower', y='peak_rpm', data=auto)

# %%
sns.lmplot(x='horsepower', y='peak_rpm', data=auto, hue='fuel_type')
